# %%
from sleepeeg.dashboard import create_dashboard
from sleepeeg.pipeline import CleaningPipe

# %% [markdown]
# If you already cleaned your data and saved the `bad_channels.txt` and `annotations.txt` files, you can skip to the section 5.

# %% [markdown]
# ### 1. Prepare data for selecting bad channels and epochs

# %%
pipe = CleaningPipe(
    path_to_eeg=r"C:\Users\Gennadiy\Documents\data\HZ4\HZ4_SLEEP_20210629_132715.mff",
    output_dir=r"C:\Users\Gennadiy\Documents\data\HZ4\processing"
)
pipe.mne_raw.load_data()
pipe.resample(sfreq=250)
pipe.filter(l_freq=0.3)
pipe.notch(freqs='50s')

# %% [markdown]
# ### 2. Select and interpolate bad channels

# %%
pipe.plot(save_bad_channels=True, overwrite=False)

# %%
pipe.interpolate_bads(reset_bads=True)

# %% [markdown]
# ### 3. Select bad_epochs

# %%
pipe.plot(save_annotations=True)

# %% [markdown]
# ### 4. (Optional) You can use ICAPipe and save ica.fif file with components selected for exclusion and provide the path to it to `create_dashboard` below.

# %% [markdown]
# ### 5. Create dashboard

# %%
create_dashboard(
    subject_code="EL3001",
    # Can be either raw .mff or filtered .fif file, but before interpolation and bad epochs selection.
    path_to_eeg=r"F:\gennadiy\ella_processed\EL3001\CleaningPipe\filtered_raw.fif",
    # If you don't have a hypnogram, set it to None.
    path_to_hypnogram=r"C:\Users\Gennadiy\Documents\ella_proj\processing\EL3001\staging.txt",
    # If you don't have a hypnogram, set it to None.
    hypno_freq=1,
    path_to_bad_channels=r"F:\gennadiy\ella_processed\EL3001\CleaningPipe\bad_channels.txt",
    path_to_annotations=r"F:\gennadiy\ella_processed\EL3001\CleaningPipe\annotations.txt",
    output_dir=r"F:\gennadiy\ella_processed\EL3001",
    # Can be either 'average', 'VREF' or 'mastoids'.
    reference="VREF",
    # New sampling frequency in Hz. Can be None, if the eeg file is already resampled.
    resampling_freq=None,
    # Provide a tuple with two frequencies, e.g., (0.3, 40) for bandpass or (0.3, None) for highpass etc.
    # Can be None if the eeg file is already filtered.
    bandpass_filter_freqs=None,
    # Channel to plot the spectrogram and PSD for.
    hypno_psd_pick=['E101'],
    # If you performed an ICA - pass here path to file with ICA components (including selection for exclusion).
    path_to_ica_fif=None,
    # Whether to save cleaned eeg file dashboard_cleaned_raw.fif.
    save_fif=False,
    # Whether to set manual topomaps power limits.
    # Should be a list of 4 tuples of 2 floats, e.g., [(0,10),(0, 30),(0,50),(10, 100)]
    topomap_cbar_limits=None
)
# Out:
# Opening raw data file F:\gennadiy\ella_processed\EL3001\CleaningPipe\filtered_raw.fif...
#     Range : 0 ... 1994499 =      0.000 ...  7977.996 secs
# Ready.
# Opening raw data file F:\gennadiy\ella_processed\EL3001\CleaningPipe\filtered_raw-1.fif...
#     Range : 1994500 ... 3988999 =   7978.000 ... 15955.996 secs
# Ready.
# Opening raw data file F:\gennadiy\ella_processed\EL3001\CleaningPipe\filtered_raw-2.fif...
#     Range : 3989000 ... 5983499 =  15956.000 ... 23933.996 secs
# Ready.
# Opening raw data file F:\gennadiy\ella_processed\EL3001\CleaningPipe\filtered_raw-3.fif...
#     Range : 5983500 ... 5985607 =  23934.000 ... 23942.428 secs
# Ready.
# Reading 0 ... 5985607  =      0.000 ... 23942.428 secs...
# EEG channel type selected for re-referencing
# Applying a custom ('EEG',) reference.
# Hypnogram is SHORTER than data by 0.43 seconds. Padding hypnogram with last value to match data.size.
# EEG channel type selected for re-referencing
# Applying a custom ('EEG',) reference.
# c:\Users\Gennadiy\Documents\eeg-processing-pipeline\sleepeeg\base.py:1280: UserWarning: Zero value in spectrum for channel VREF
#   self._check_values()
# c:\Users\Gennadiy\Documents\eeg-processing-pipeline\sleepeeg\base.py:1280: UserWarning: Zero value in spectrum for channel VREF
#   self._check_values()
# c:\Users\Gennadiy\Documents\eeg-processing-pipeline\sleepeeg\base.py:1280: UserWarning: Zero value in spectrum for channel VREF
#   self._check_values()
# c:\Users\Gennadiy\Documents\eeg-processing-pipeline\sleepeeg\base.py:1280: UserWarning: Zero value in spectrum for channel VREF
#   self._check_values()
# c:\Users\Gennadiy\Documents\eeg-processing-pipeline\sleepeeg\base.py:1280: UserWarning: Zero value in spectrum for channel VREF
#   self._check_values()
# Interpolating bad channels
#     Automatic origin fit: head of radius 96.5 mm
# Computing interpolation matrix from 234 sensor positions
# Interpolating 23 sensors
# c:\Users\Gennadiy\Documents\eeg-processing-pipeline\sleepeeg\pipeline.py:118: RuntimeWarning: Limited 2 annotation(s) that were expanding outside the data range.
#   self.mne_raw.set_annotations(read_annotations(p))
# Hypnogram is SHORTER than data by 0.43 seconds. Padding hypnogram with last value to match data.size.
# EEG channel type selected for re-referencing
# Applying a custom ('EEG',) reference.
# Setting 289553 of 5985608 (4.84%) samples to NaN, retaining 5696055 (95.16%) samples.
# c:\Users\Gennadiy\Documents\eeg-processing-pipeline\sleepeeg\base.py:1280: UserWarning: Zero value in spectrum for channel VREF
#   self._check_values()
# Setting 289553 of 5985608 (4.84%) samples to NaN, retaining 5696055 (95.16%) samples.
# c:\Users\Gennadiy\Documents\eeg-processing-pipeline\sleepeeg\base.py:1280: UserWarning: Zero value in spectrum for channel VREF
#   self._check_values()
# Setting 289553 of 5985608 (4.84%) samples to NaN, retaining 5696055 (95.16%) samples.
# c:\Users\Gennadiy\Documents\eeg-processing-pipeline\sleepeeg\base.py:1280: UserWarning: Zero value in spectrum for channel VREF
#   self._check_values()
# Setting 289553 of 5985608 (4.84%) samples to NaN, retaining 5696055 (95.16%) samples.
# c:\Users\Gennadiy\Documents\eeg-processing-pipeline\sleepeeg\base.py:1280: UserWarning: Zero value in spectrum for channel VREF
#   self._check_values()
# Setting 289553 of 5985608 (4.84%) samples to NaN, retaining 5696055 (95.16%) samples.
# c:\Users\Gennadiy\Documents\eeg-processing-pipeline\sleepeeg\base.py:1280: UserWarning: Zero value in spectrum for channel VREF
#   self._check_values()
# Setting 289553 of 5985608 (4.84%) samples to NaN, retaining 5696055 (95.16%) samples.
# EEG channel type selected for re-referencing
# Applying average reference.
# Applying a custom ('EEG',) reference.
# Setting 289553 of 5985608 (4.84%) samples to NaN, retaining 5696055 (95.16%) samples.
# Setting 289553 of 5985608 (4.84%) samples to NaN, retaining 5696055 (95.16%) samples.
# Setting 289553 of 5985608 (4.84%) samples to NaN, retaining 5696055 (95.16%) samples.
# Setting 289553 of 5985608 (4.84%) samples to NaN, retaining 5696055 (95.16%) samples.
# Setting 289553 of 5985608 (4.84%) samples to NaN, retaining 5696055 (95.16%) samples.
